# %%
# !pip install datasets
# Out:
# Requirement already satisfied: datasets in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (2.18.0)
# Requirement already satisfied: pyarrow>=12.0.0 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from datasets) (16.1.0)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from datasets) (4.66.2)
# Requirement already satisfied: packaging in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from datasets) (24.1)
# Requirement already satisfied: pandas in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from datasets) (2.0.3)
# Requirement already satisfied: fsspec[http]<=2024.2.0,>=2023.1.0 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from datasets) (2024.2.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from datasets) (2.31.0)
# Requirement already satisfied: xxhash in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from datasets) (3.4.1)
# Requirement already satisfied: huggingface-hub>=0.19.4 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from datasets) (0.22.2)
# Requirement already satisfied: filelock in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from datasets) (3.13.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from datasets) (1.22.4)
# Requirement already satisfied: multiprocess in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: pyarrow-hotfix in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiohttp in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from datasets) (3.9.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from huggingface-hub>=0.19.4->datasets) (4.11.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from requests>=2.19.0->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from requests>=2.19.0->datasets) (1.26.19)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: colorama in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from tqdm>=4.62.1->datasets) (0.4.6)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.12.0)
# WARNING: You are using pip version 20.3.4; however, version 24.1 is available.
# You should consider upgrading via the 'C:\Users\Administrator\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datasets import list_datasets, load_dataset
import warnings

pd.set_option('display.max_columns', None)
warnings.simplefilter(action="ignore")

# %% [markdown]
# ---

# %% [markdown]
# ### Load Emotion dataset:

# %%
# Loading the dataset
emotion_dataset = load_dataset('emotion')
print("\n", emotion_dataset)
# Out:
# Downloading builder script:   0%|          | 0.00/3.97k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/3.28k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/8.78k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/592k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/74.0k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/74.9k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/16000 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2000 [00:00<?, ? examples/s]
#  DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 16000
#     })
#     validation: Dataset({
#         features: ['text', 'label'],
#         num_rows: 2000
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 2000
#     })
# })

# %%
# Print various details about the 'emotion_dataset'
print("Dataset Items: \n", emotion_dataset.items())
print("\nDataset type: \n", type(emotion_dataset))
print("\nShape of dataset: \n", emotion_dataset.shape)
print("\nNo of rows: \n", emotion_dataset.num_rows)
print("\nNo of columns: \n", emotion_dataset.num_columns)
# Out:
# Dataset Items:
#  dict_items([('train', Dataset({
#     features: ['text', 'label'],
#     num_rows: 16000
# })), ('validation', Dataset({
#     features: ['text', 'label'],
#     num_rows: 2000
# })), ('test', Dataset({
#     features: ['text', 'label'],
#     num_rows: 2000
# }))])
#
# Dataset type:
#  <class 'datasets.dataset_dict.DatasetDict'>
#
# Shape of dataset:
#  {'train': (16000, 2), 'validation': (2000, 2), 'test': (2000, 2)}
#
# No of rows:
#  {'train': 16000, 'validation': 2000, 'test': 2000}
#
# No of columns:
#  {'train': 2, 'validation': 2, 'test': 2}

# %%
# Load the 'emotion' dataset and its splits
emotion_train = load_dataset('emotion', split='train')
emotion_val = load_dataset('emotion', split='validation')
emotion_test = load_dataset('emotion', split='test')

# Display details of the 'emotion' dataset splits
print("\n\nDetails for Emotion Train Dataset: ", emotion_train.shape)
print("Details for Emotion Validation Dataset: ", emotion_val.shape)
print("Details for Emotion Test Dataset: ", emotion_test.shape)
# Out:
# Details for Emotion Train Dataset:  (16000, 2)
# Details for Emotion Validation Dataset:  (2000, 2)
# Details for Emotion Test Dataset:  (2000, 2)

# %%
print("\nTrain Dataset Features for Emotion: \n", emotion_train.features)
print("\nTest Dataset Features for Emotion: \n", emotion_val.features)
print("\nTest Dataset Features for Emotion: \n", emotion_test.features)
# Out:
# Train Dataset Features for Emotion:
#  {'text': Value(dtype='string', id=None), 'label': ClassLabel(names=['sadness', 'joy', 'love', 'anger', 'fear', 'surprise'], id=None)}
#
# Test Dataset Features for Emotion:
#  {'text': Value(dtype='string', id=None), 'label': ClassLabel(names=['sadness', 'joy', 'love', 'anger', 'fear', 'surprise'], id=None)}
#
# Test Dataset Features for Emotion:
#  {'text': Value(dtype='string', id=None), 'label': ClassLabel(names=['sadness', 'joy', 'love', 'anger', 'fear', 'surprise'], id=None)}

# %% [markdown]
# ### Read sample text of different categories:

# %%
# Print specific samples from the 'emotion' training dataset
print(emotion_dataset['train']['text'][0])
print(emotion_dataset['train']['label'][0])
print()

print(emotion_dataset['train']['text'][6000])
print(emotion_dataset['train']['label'][6000])
print()

print(emotion_dataset['train']['text'][100])
print(emotion_dataset['train']['label'][100])
print()

print(emotion_dataset['train']['text'][3700])
print(emotion_dataset['train']['label'][3700])
print()

print(emotion_dataset['train']['text'][7100])
print(emotion_dataset['train']['label'][7100])
print()

print(emotion_dataset['train']['text'][5400])
print(emotion_dataset['train']['label'][5400])
# Out:
# i didnt feel humiliated
# 0
#
# i feel quite content right now s i mean nothing amazing happened just a stupid frenh competition where im sure i did shit and tutor but i dontt know i feel ok
# 1
#
# i wont let me child cry it out because i feel that loving her and lily when she was little was going to be opportunities that only lasted for those short few months
# 2
#
# i hate being so hungry and weak that i feel stubborn and dont want to do anything productive
# 3
#
# i always feel pressured to socialize or i get eight missed calls and some texts from my host brother in the span of an hour
# 4
#
# i have chose for myself that makes me feel amazing
# 5

# %% [markdown]
# ---

# %% [markdown]
# ### Convert dataset object to DataFrame:

# %%
emotion_train_df = pd.DataFrame(data=emotion_train)
emotion_val_df = pd.DataFrame(data=emotion_val)
emotion_test_df = pd.DataFrame(data=emotion_test)

# %%
emotion_train_df.head(10)
# Out:
#                                                 text  label
# 0                            i didnt feel humiliated      0
# 1  i can go from feeling so hopeless to so damned...      0
# 2   im grabbing a minute to post i feel greedy wrong      3
# 3  i am ever feeling nostalgic about the fireplac...      2
# 4                               i am feeling grouchy      3
# 5  ive been feeling a little burdened lately wasn...      0
# 6  ive been taking or milligrams or times recomme...      5
# 7  i feel as confused about life as a teenager or...      4
# 8  i have been with petronas for years i feel tha...      1
# 9                                i feel romantic too      2

# %%
emotion_train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16000 entries, 0 to 15999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    16000 non-null  object
#  1   label   16000 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 250.1+ KB

# %%
emotion_train_df.isnull().sum()
# Out:
# text     0
# label    0
# dtype: int64

# %%
emotion_train_df.groupby("label").describe()
# Out:
#        text
#       count unique                                                top freq
# label
# 0      4666   4666                            i didnt feel humiliated    1
# 1      5362   5361  i feel more adventurous willing to take risks ...    2
# 2      1304   1304  i am ever feeling nostalgic about the fireplac...    1
# 3      2159   2159   im grabbing a minute to post i feel greedy wrong    1
# 4      1937   1937  i feel as confused about life as a teenager or...    1
# 5       572    572  ive been taking or milligrams or times recomme...    1

# %%
label_names = ['sadness', 'joy', 'love', 'anger', 'fear', 'surprise']

# %% [markdown]
# ---

# %% [markdown]
# ### Create new feature:

# %%
# Add a new column "text_length" to the DataFrame to store the text lengths
emotion_train_df["text_length"] = emotion_train_df["text"].apply(len)

# Display the first few rows of the DataFrame with the new column
emotion_train_df.head()
# Out:
#                                                 text  label  text_length
# 0                            i didnt feel humiliated      0           23
# 1  i can go from feeling so hopeless to so damned...      0          108
# 2   im grabbing a minute to post i feel greedy wrong      3           48
# 3  i am ever feeling nostalgic about the fireplac...      2           92
# 4                               i am feeling grouchy      3           20

# %% [markdown]
# ---

# %% [markdown]
# ### Data Visualization:

# %%
# Add a new column "text_length" to the DataFrame to store the text lengths
emotion_train_df["text_length"] = emotion_train_df["text"].apply(len)

# Display the first few rows
emotion_train_df.head()
# Out:
#                                                 text  label  text_length
# 0                            i didnt feel humiliated      0           23
# 1  i can go from feeling so hopeless to so damned...      0          108
# 2   im grabbing a minute to post i feel greedy wrong      3           48
# 3  i am ever feeling nostalgic about the fireplac...      2           92
# 4                               i am feeling grouchy      3           20

# %%
# Define a mapping dictionary to map numeric labels to emotion names
label_dict = {0: "sadness", 1: "joy", 2: "love", 3: "anger", 4: "fear", 5: "surprise"}

# Map numeric labels to emotion names and add a new "label_names" column
emotion_train_df["label_names"] = emotion_train_df["label"].map(label_dict)

# Display the first few rows
emotion_train_df.head()
# Out:
#                                                 text  label  text_length  \
# 0                            i didnt feel humiliated      0           23
# 1  i can go from feeling so hopeless to so damned...      0          108
# 2   im grabbing a minute to post i feel greedy wrong      3           48
# 3  i am ever feeling nostalgic about the fireplac...      2           92
# 4                               i am feeling grouchy      3           20
#
#   label_names
# 0     sadness
# 1     sadness
# 2       anger
# 3        love
# 4       anger

# %%
# Create a grouped histogram of text lengths by emotion label
emotion_train_df.hist(column="text_length", by="label_names", figsize=(20, 10), grid=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 2
#       1 # Create a grouped histogram of text lengths by emotion label
# ----> 2 emotion_train_df.hist(column="text_length", by="label_names", figsize=(20, 10), grid=True)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_core.py:223, in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     134 """
#     135 Make a histogram of the DataFrame's columns.
#     136
#    (...)
#     220     >>> hist = df.hist(bins=3)
#     221 """
#     222 plot_backend = _get_plot_backend(backend)
# --> 223 return plot_backend.hist_frame(
#     224     data,
#     225     column=column,
#     226     by=by,
#     227     grid=grid,
#     228     xlabelsize=xlabelsize,
#     229     xrot=xrot,
#     230     ylabelsize=ylabelsize,
#     231     yrot=yrot,
#     232     ax=ax,
#     233     sharex=sharex,
#     234     sharey=sharey,
#     235     figsize=figsize,
#     236     layout=layout,
#     237     legend=legend,
#     238     bins=bins,
#     239     **kwargs,
#     240 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_matplotlib\hist.py:483, in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, legend, **kwds)
#     481     raise ValueError("Cannot use both legend and label")
#     482 if by is not None:
# --> 483     axes = _grouped_hist(
#     484         data,
#     485         column=column,
#     486         by=by,
#     487         ax=ax,
#     488         grid=grid,
#     489         figsize=figsize,
#     490         sharex=sharex,
#     491         sharey=sharey,
#     492         layout=layout,
#     493         bins=bins,
#     494         xlabelsize=xlabelsize,
#     495         xrot=xrot,
#     496         ylabelsize=ylabelsize,
#     497         yrot=yrot,
#     498         legend=legend,
#     499         **kwds,
#     500     )
#     501     return axes
#     503 if column is not None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_matplotlib\hist.py:367, in _grouped_hist(data, column, by, ax, bins, figsize, layout, sharex, sharey, rot, grid, xlabelsize, xrot, ylabelsize, yrot, legend, **kwargs)
#     364 if xrot is None:
#     365     xrot = rot
# --> 367 fig, axes = _grouped_plot(
#     368     plot_group,
#     369     data,
#     370     column=column,
#     371     by=by,
#     372     sharex=sharex,
#     373     sharey=sharey,
#     374     ax=ax,
#     375     figsize=figsize,
#     376     layout=layout,
#     377     rot=rot,
#     378 )
#     380 set_ticks_props(
#     381     axes, xlabelsize=xlabelsize, xrot=xrot, ylabelsize=ylabelsize, yrot=yrot
#     382 )
#     384 maybe_adjust_figure(
#     385     fig, bottom=0.15, top=0.9, left=0.1, right=0.9, hspace=0.5, wspace=0.3
#     386 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_matplotlib\hist.py:292, in _grouped_plot(plotf, data, column, by, numeric_only, figsize, sharex, sharey, layout, rot, ax, **kwargs)
#     289     grouped = grouped[column]
#     291 naxes = len(grouped)
# --> 292 fig, axes = create_subplots(
#     293     naxes=naxes, figsize=figsize, sharex=sharex, sharey=sharey, ax=ax, layout=layout
#     294 )
#     296 _axes = flatten_axes(axes)
#     298 for i, (key, group) in enumerate(grouped):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_matplotlib\tools.py:300, in create_subplots(naxes, sharex, sharey, squeeze, subplot_kw, ax, layout, layout_type, **fig_kw)
#     297     for ax in axarr[naxes:]:
#     298         ax.set_visible(False)
# --> 300 handle_shared_axes(axarr, nplots, naxes, nrows, ncols, sharex, sharey)
#     302 if squeeze:
#     303     # Reshape the array to have the final desired dimension (nrow,ncol),
#     304     # though discarding unneeded dimensions that equal 1.  If we only have
#     305     # one subplot, just return it instead of a 1-element array.
#     306     if nplots == 1:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_matplotlib\tools.py:404, in handle_shared_axes(axarr, nplots, naxes, nrows, ncols, sharex, sharey)
#     402 layout = np.zeros((nrows + 1, ncols + 1), dtype=np.bool_)
#     403 for ax in axarr:
# --> 404     layout[row_num(ax), col_num(ax)] = ax.get_visible()
#     406 for ax in axarr:
#     407     # only the last row of subplots should get x labels -> all
#     408     # other off layout handles the case that the subplot is
#     409     # the last in the column, because below is no subplot/gap.
#     410     if not layout[row_num(ax) + 1, col_num(ax)]:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_matplotlib\tools.py:393, in handle_shared_axes.<locals>.<lambda>(x)
#     383 def handle_shared_axes(
#     384     axarr: Iterable[Axes],
#     385     nplots: int,
#    (...)
#     390     sharey: bool,
#     391 ) -> None:
#     392     if nplots > 1:
# --> 393         row_num = lambda x: x.get_subplotspec().rowspan.start
#     394         col_num = lambda x: x.get_subplotspec().colspan.start
#     396         is_first_col = lambda x: x.get_subplotspec().is_first_col()
#
# AttributeError: 'SubplotSpec' object has no attribute 'rowspan'

# %%
# Check and print the count of null values in the test and validation DataFrame
print(emotion_val_df.isnull().sum())
print(emotion_test_df.isnull().sum())
# Out:
# text     0
# label    0
# dtype: int64
# text     0
# label    0
# dtype: int64

# %%
emotion_val_df.groupby("label").describe()
# Out:
#        text
#       count unique                                                top freq
# label
# 0       550    550  im feeling quite sad and sorry for myself but ...    1
# 1       704    704  i can have for a treat or if i am feeling festive    1
# 2       178    178                     i feel like a faithful servant    1
# 3       275    275                  i am just feeling cranky and blue    1
# 4       212    212  i just know to begin with i am going to feel s...    1
# 5        81     81                     i feel a funny mix of emotions    1

# %%
emotion_test_df.groupby("label").describe()
# Out:
#        text
#       count unique                                                top freq
# label
# 0       581    581  im feeling rather rotten so im not very ambiti...    1
# 1       695    695  i left with my bouquet of red and yellow tulip...    1
# 2       159    159  i find myself in the odd position of feeling s...    1
# 3       275    275   i felt anger when at the end of a telephone call    1
# 4       224    224  i cant walk into a shop anywhere where i do no...    1
# 5        66     66  i feel a little stunned but can t imagine what...    1

# %%
# Calculate and add a new column "text_length" with text lengths
emotion_val_df["text_length"] = emotion_val_df["text"].apply(len)

# Map numeric labels to emotion names and add a new "label_names" column
emotion_val_df["label_names"] = emotion_val_df["label"].map(label_dict)

# Display the first few rows
emotion_val_df.head()
# Out:
#                                                 text  label  text_length  \
# 0  im feeling quite sad and sorry for myself but ...      0           69
# 1  i feel like i am still looking at a blank canv...      0           70
# 2                     i feel like a faithful servant      2           30
# 3                  i am just feeling cranky and blue      3           33
# 4  i can have for a treat or if i am feeling festive      1           49
#
#   label_names
# 0     sadness
# 1     sadness
# 2        love
# 3       anger
# 4         joy

# %%
# Calculate and add a new column "text_length" with text lengths
emotion_test_df["text_length"] = emotion_test_df["text"].apply(len)

# Map numeric labels to emotion names and add a new "label_names" column
emotion_test_df["label_names"] = emotion_test_df["label"].map(label_dict)

# Display the first few rows
emotion_test_df.head()
# Out:
#                                                 text  label  text_length  \
# 0  im feeling rather rotten so im not very ambiti...      0           59
# 1          im updating my blog because i feel shitty      0           41
# 2  i never make her separate from me because i do...      0           97
# 3  i left with my bouquet of red and yellow tulip...      1          113
# 4    i was feeling a little vain when i did this one      0           47
#
#   label_names
# 0     sadness
# 1     sadness
# 2     sadness
# 3         joy
# 4     sadness

# %%
# Create a histogram plot of the "text_length" column in the validation DataFrame
plt.figure(figsize=(14, 6))  # Set the figure size
emotion_val_df["text_length"].plot.hist(bins=100, grid=True)  # Plot a histogram with 100 bins and grid lines

# %%
# Create a histogram plot of the "text_length" column in the test DataFrame
plt.figure(figsize=(14,6))
emotion_test_df["text_length"].plot.hist(bins=100, grid=True)

# %%
emotion_val_df.hist(column="text_length", by="label_names", figsize=(20,10), grid=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 emotion_val_df.hist(column="text_length", by="label_names", figsize=(20,10), grid=True)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_core.py:223, in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     134 """
#     135 Make a histogram of the DataFrame's columns.
#     136
#    (...)
#     220     >>> hist = df.hist(bins=3)
#     221 """
#     222 plot_backend = _get_plot_backend(backend)
# --> 223 return plot_backend.hist_frame(
#     224     data,
#     225     column=column,
#     226     by=by,
#     227     grid=grid,
#     228     xlabelsize=xlabelsize,
#     229     xrot=xrot,
#     230     ylabelsize=ylabelsize,
#     231     yrot=yrot,
#     232     ax=ax,
#     233     sharex=sharex,
#     234     sharey=sharey,
#     235     figsize=figsize,
#     236     layout=layout,
#     237     legend=legend,
#     238     bins=bins,
#     239     **kwargs,
#     240 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_matplotlib\hist.py:483, in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, legend, **kwds)
#     481     raise ValueError("Cannot use both legend and label")
#     482 if by is not None:
# --> 483     axes = _grouped_hist(
#     484         data,
#     485         column=column,
#     486         by=by,
#     487         ax=ax,
#     488         grid=grid,
#     489         figsize=figsize,
#     490         sharex=sharex,
#     491         sharey=sharey,
#     492         layout=layout,
#     493         bins=bins,
#     494         xlabelsize=xlabelsize,
#     495         xrot=xrot,
#     496         ylabelsize=ylabelsize,
#     497         yrot=yrot,
#     498         legend=legend,
#     499         **kwds,
#     500     )
#     501     return axes
#     503 if column is not None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_matplotlib\hist.py:367, in _grouped_hist(data, column, by, ax, bins, figsize, layout, sharex, sharey, rot, grid, xlabelsize, xrot, ylabelsize, yrot, legend, **kwargs)
#     364 if xrot is None:
#     365     xrot = rot
# --> 367 fig, axes = _grouped_plot(
#     368     plot_group,
#     369     data,
#     370     column=column,
#     371     by=by,
#     372     sharex=sharex,
#     373     sharey=sharey,
#     374     ax=ax,
#     375     figsize=figsize,
#     376     layout=layout,
#     377     rot=rot,
#     378 )
#     380 set_ticks_props(
#     381     axes, xlabelsize=xlabelsize, xrot=xrot, ylabelsize=ylabelsize, yrot=yrot
#     382 )
#     384 maybe_adjust_figure(
#     385     fig, bottom=0.15, top=0.9, left=0.1, right=0.9, hspace=0.5, wspace=0.3
#     386 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_matplotlib\hist.py:292, in _grouped_plot(plotf, data, column, by, numeric_only, figsize, sharex, sharey, layout, rot, ax, **kwargs)
#     289     grouped = grouped[column]
#     291 naxes = len(grouped)
# --> 292 fig, axes = create_subplots(
#     293     naxes=naxes, figsize=figsize, sharex=sharex, sharey=sharey, ax=ax, layout=layout
#     294 )
#     296 _axes = flatten_axes(axes)
#     298 for i, (key, group) in enumerate(grouped):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_matplotlib\tools.py:300, in create_subplots(naxes, sharex, sharey, squeeze, subplot_kw, ax, layout, layout_type, **fig_kw)
#     297     for ax in axarr[naxes:]:
#     298         ax.set_visible(False)
# --> 300 handle_shared_axes(axarr, nplots, naxes, nrows, ncols, sharex, sharey)
#     302 if squeeze:
#     303     # Reshape the array to have the final desired dimension (nrow,ncol),
#     304     # though discarding unneeded dimensions that equal 1.  If we only have
#     305     # one subplot, just return it instead of a 1-element array.
#     306     if nplots == 1:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_matplotlib\tools.py:404, in handle_shared_axes(axarr, nplots, naxes, nrows, ncols, sharex, sharey)
#     402 layout = np.zeros((nrows + 1, ncols + 1), dtype=np.bool_)
#     403 for ax in axarr:
# --> 404     layout[row_num(ax), col_num(ax)] = ax.get_visible()
#     406 for ax in axarr:
#     407     # only the last row of subplots should get x labels -> all
#     408     # other off layout handles the case that the subplot is
#     409     # the last in the column, because below is no subplot/gap.
#     410     if not layout[row_num(ax) + 1, col_num(ax)]:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_matplotlib\tools.py:393, in handle_shared_axes.<locals>.<lambda>(x)
#     383 def handle_shared_axes(
#     384     axarr: Iterable[Axes],
#     385     nplots: int,
#    (...)
#     390     sharey: bool,
#     391 ) -> None:
#     392     if nplots > 1:
# --> 393         row_num = lambda x: x.get_subplotspec().rowspan.start
#     394         col_num = lambda x: x.get_subplotspec().colspan.start
#     396         is_first_col = lambda x: x.get_subplotspec().is_first_col()
#
# AttributeError: 'SubplotSpec' object has no attribute 'rowspan'

# %%
emotion_test_df.hist(column="text_length", by="label_names", figsize=(20,10), grid=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa6197c4190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa6191f3990>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa619172310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa619128890>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa6190dbe10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa61909c3d0>]],
#       dtype=object)

# %% [markdown]
# ---
